# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
# !pip install pyreadstat
import pyreadstat #since the data files are .xpt files, this library is needed to import the table
import re
import requests
from bs4 import BeautifulSoup
from nhanes_utils import to_snake_case, get_common_nan_ids, standardize_id_column, drop_rows_with_common_nan_ids
# Out:
# Requirement already satisfied: pyreadstat in /Users/Rachel/anaconda3/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: pandas>=1.2.0 in /Users/Rachel/anaconda3/lib/python3.10/site-packages (from pyreadstat) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/Rachel/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.0->pyreadstat) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Rachel/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.0->pyreadstat) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/Rachel/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.0->pyreadstat) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/Rachel/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyreadstat) (1.16.0)

# %%
file_path = '2017-2020/P_PAQ.xpt'

df, meta = pyreadstat.read_xport(file_path)
df = standardize_id_column(df)

# %%
df.head()
# Out:
#    participant_id  PAQ605  PAQ610  PAD615  PAQ620  PAQ625  PAD630  PAQ635  \
# 0        109266.0     2.0     NaN     NaN     2.0     NaN     NaN     2.0
# 1        109267.0     2.0     NaN     NaN     2.0     NaN     NaN     2.0
# 2        109268.0     1.0     5.0   540.0     1.0     5.0   300.0     2.0
# 3        109271.0     2.0     NaN     NaN     1.0     2.0   120.0     2.0
# 4        109273.0     1.0     3.0   240.0     2.0     NaN     NaN     2.0
#
#    PAQ640  PAD645  PAQ650  PAQ655  PAD660  PAQ665  PAQ670  PAD675  PAD680
# 0     NaN     NaN     1.0     5.0    60.0     1.0     4.0    30.0   480.0
# 1     NaN     NaN     1.0     6.0    90.0     2.0     NaN     NaN   540.0
# 2     NaN     NaN     2.0     NaN     NaN     2.0     NaN     NaN   540.0
# 3     NaN     NaN     2.0     NaN     NaN     2.0     NaN     NaN    60.0
# 4     NaN     NaN     2.0     NaN     NaN     1.0     4.0   120.0   180.0

# %%
url = "https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles/P_PAQ.htm"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

pattern = re.compile(r'^([A-Z0-9_]+)\s*-\s*(.+)$')

rename_dict = {}

# Loop through all h3 tags and filter those that match our pattern
for tag in soup.find_all('h3'):
    text = tag.get_text(strip=True)
    match = pattern.match(text)
    if match:
        var_name = match.group(1)
        description = match.group(2)
                
        clean_name = to_snake_case(description)
        rename_dict[var_name] = clean_name

# %%
filtered_rename_dict = {
    k: v for k, v in rename_dict.items() if k in df.columns
}

df = df.rename(columns=filtered_rename_dict)

# %%
df.head()
# Out:
#    participant_id  vigorous_work_activity  number_of_days_vigorous_work  \
# 0        109266.0                     2.0                           NaN
# 1        109267.0                     2.0                           NaN
# 2        109268.0                     1.0                           5.0
# 3        109271.0                     2.0                           NaN
# 4        109273.0                     1.0                           3.0
#
#    minutes_vigorous_intensity_work  moderate_work_activity  \
# 0                              NaN                     2.0
# 1                              NaN                     2.0
# 2                            540.0                     1.0
# 3                              NaN                     1.0
# 4                            240.0                     2.0
#
#    number_of_days_moderate_work  minutes_moderate_intensity_work  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           5.0                            300.0
# 3                           2.0                            120.0
# 4                           NaN                              NaN
#
#    walk_or_bicycle  number_of_days_walk_or_bicycle  \
# 0              2.0                             NaN
# 1              2.0                             NaN
# 2              2.0                             NaN
# 3              2.0                             NaN
# 4              2.0                             NaN
#
#    minutes_walk_bicycle_for_transportation  vigorous_recreational_activities  \
# 0                                      NaN                               1.0
# 1                                      NaN                               1.0
# 2                                      NaN                               2.0
# 3                                      NaN                               2.0
# 4                                      NaN                               2.0
#
#    days_vigorous_recreational_activities  \
# 0                                    5.0
# 1                                    6.0
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    minutes_vigorous_recreational_activities  moderate_recreational_activities  \
# 0                                      60.0                               1.0
# 1                                      90.0                               2.0
# 2                                       NaN                               2.0
# 3                                       NaN                               2.0
# 4                                       NaN                               1.0
#
#    days_moderate_recreational_activities  \
# 0                                    4.0
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    4.0
#
#    minutes_moderate_recreational_activities  minutes_sedentary_activity
# 0                                      30.0                       480.0
# 1                                       NaN                       540.0
# 2                                       NaN                       540.0
# 3                                       NaN                        60.0
# 4                                     120.0                       180.0

# %%
df.isna().sum()
# Out:
# participant_id                                 0
# vigorous_work_activity                         0
# number_of_days_vigorous_work                7275
# minutes_vigorous_intensity_work             7291
# moderate_work_activity                         0
# number_of_days_moderate_work                5506
# minutes_moderate_intensity_work             5529
# walk_or_bicycle                                0
# number_of_days_walk_or_bicycle              7440
# minutes_walk_bicycle_for_transportation     7452
# vigorous_recreational_activities               0
# days_vigorous_recreational_activities       7271
# minutes_vigorous_recreational_activities    7276
# moderate_recreational_activities               0
# days_moderate_recreational_activities       5789
# minutes_moderate_recreational_activities    5800
# minutes_sedentary_activity                    17
# dtype: int64

# %%
df.shape
# Out:
# (9693, 17)
