# %%
import pandas as pd
import numpy as np
import pyreadstat
from sqlalchemy import create_engine
from nhanes_utils import (
    to_snake_case, 
    get_common_nan_ids, 
    standardize_id_column, 
    drop_rows_with_common_nan_ids,
    save_to_postgres,
    load_xpt,
    validate
)

# -------------------------------
# CONFIG
# -------------------------------

DB_URI = 'postgresql://postgres:rsc@localhost:5432/NHANES_20172020'
engine = create_engine(DB_URI)

# %% [markdown]
# #### Demographics

# %%
DATA_PATH_DEMO = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/2017-2020.P_DEMO.xpt'
df = load_xpt(DATA_PATH_DEMO)
save_to_postgres(df, "raw_demographics", engine)
# Out:
# raw_demographics saved to PostgreSQL

# %% [markdown]
# #### Anthropometry

# %%
DATA_PATH_BMX = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/2017-2020.P_BMX.xpt'
df = load_xpt(DATA_PATH_BMX)
save_to_postgres(df, "raw_bmx", engine)
# Out:
# raw_bmx saved to PostgreSQL

# %% [markdown]
# #### Blood Pressure

# %%
BP = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/BPOscillometric_P_BPXO.xpt'
df = load_xpt(BP)
save_to_postgres(df, "raw_blood_pressure", engine)
# Out:
# raw_blood_pressure saved to PostgreSQL

# %% [markdown]
# #### Urine Labs

# %%
ALBCR = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/1.P_ALB_CR.xpt'
df = load_xpt(ALBCR)
save_to_postgres(df, "raw_urine_albcr", engine)
# Out:
# raw_urine_albcr saved to PostgreSQL

# %%
ARSENIC_TOTAL = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/2.P_UTAS.xpt'
df = load_xpt(ARSENIC_TOTAL)
save_to_postgres(df, "raw_urine_total_arsenic", engine)
# Out:
# raw_urine_total_arsenic saved to PostgreSQL

# %%
ARSENIC_SPECIATED = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/3.P_UAS.xpt'
df = load_xpt(ARSENIC_SPECIATED)
save_to_postgres(df, "raw_urine_speciated_arsenic", engine)
# Out:
# raw_urine_speciated_arsenic saved to PostgreSQL

# %%
CHROM = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/4.P_UCM.xpt'
df = load_xpt(CHROM)
save_to_postgres(df, "raw_urine_chromium", engine)
# Out:
# raw_urine_chromium saved to PostgreSQL

# %%
FR = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/5.P_FR.xpt'
df = load_xpt(FR)
save_to_postgres(df, "raw_urine_flame_retardants", engine)
# Out:
# raw_urine_flame_retardants saved to PostgreSQL

# %%
FR_SURP = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/6.P_SSFR.xpt'
df = load_xpt(FR_SURP)
save_to_postgres(df, "raw_urine_flame_retardants_surplus", engine)
# Out:
# raw_urine_flame_retardants_surplus saved to PostgreSQL

# %%
IO = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/7.P_UIO.xpt'
df = load_xpt(IO)
save_to_postgres(df, "raw_urine_iodine", engine)
# Out:
# raw_urine_iodine saved to PostgreSQL

# %%
MERC = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/8.P_UHG.xpt'
df = load_xpt(MERC)
save_to_postgres(df, "raw_urine_mercury", engine)
# Out:
# raw_urine_mercury saved to PostgreSQL

# %%
METALS = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/9.P_UM.xpt'
df = load_xpt(METALS)
save_to_postgres(df, "raw_urine_metals", engine)
# Out:
# raw_urine_metals saved to PostgreSQL

# %%
NICKEL = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/10.P_UNI.xpt'
df = load_xpt(NICKEL)
save_to_postgres(df, "raw_urine_nickel", engine)
# Out:
# raw_urine_nickel saved to PostgreSQL

# %%
ORG_INSE = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/11.P_OPD.xpt'
df = load_xpt(ORG_INSE)
save_to_postgres(df, "raw_urine_insecticide", engine)
# Out:
# raw_urine_insecticide saved to PostgreSQL

# %%
PERNT = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/12.P_PERNT.xpt'
df = load_xpt(PERNT)
save_to_postgres(df, "raw_urine_perc_nit_thio", engine)
# Out:
# raw_urine_perc_nit_thio saved to PostgreSQL

# %%
UPREG = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/13.P_UCPREG.xpt'
df = load_xpt(UPREG)
save_to_postgres(df, "raw_urine_pregnancy", engine)
# Out:
# raw_urine_pregnancy saved to PostgreSQL

# %%
UVOC = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/14.P_UVOC.xpt'
df = load_xpt(UVOC)
save_to_postgres(df, "raw_urine_voc", engine)
# Out:
# raw_urine_voc saved to PostgreSQL

# %%
UVOC2 = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/urine/15.P_UVOC2.xpt'
df = load_xpt(UVOC2)
save_to_postgres(df, "raw_urine_voc_2", engine)
# Out:
# raw_urine_voc_2 saved to PostgreSQL

# %% [markdown]
# #### Blood Labs

# %%
AGP = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/1.P_SSAGP.xpt'
df = load_xpt(AGP)
save_to_postgres(df, "raw_blood_agp", engine)
# Out:
# raw_blood_agp saved to PostgreSQL

# %%
HDL = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/2.P_HDL.xpt'
df = load_xpt(HDL)
save_to_postgres(df, "raw_blood_hdl", engine)
# Out:
# raw_blood_hdl saved to PostgreSQL

# %%
TRIG = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/3.P_TRIGLY.xpt'
df = load_xpt(TRIG)
save_to_postgres(df, "raw_blood_triglyceride", engine)
# Out:
# raw_blood_triglyceride saved to PostgreSQL

# %%
TCHOL = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/4.P_TCHOL.xpt'
df = load_xpt(TCHOL)
save_to_postgres(df, "raw_blood_total_cholesterol", engine)
# Out:
# raw_blood_total_cholesterol saved to PostgreSQL

# %%
CRCO = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/5.P_CRCO.xpt'
df = load_xpt(CRCO)
save_to_postgres(df, "raw_blood_chromium_cobalt", engine)
# Out:
# raw_blood_chromium_cobalt saved to PostgreSQL

# %%
CBC = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/6.P_CBC.xpt'
df = load_xpt(CBC)
save_to_postgres(df, "raw_blood_cbc", engine)
# Out:
# raw_blood_cbc saved to PostgreSQL

# %%
COT = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/7.P_COT.xpt'
df = load_xpt(COT)
save_to_postgres(df, "raw_blood_cotinine", engine)
# Out:
# raw_blood_cotinine saved to PostgreSQL

# %%
CMV = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/8.P_CMV.xpt'
df = load_xpt(CMV)
save_to_postgres(df, "raw_blood_cmv", engine)
# Out:
# raw_blood_cmv saved to PostgreSQL

# %%
ETHOX = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/9.P_ETHOX.xpt'
df = load_xpt(ETHOX)
save_to_postgres(df, "raw_blood_ethylene_oxide", engine)
# Out:
# raw_blood_ethylene_oxide saved to PostgreSQL

# %%
FER = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/10.P_FERTIN.xpt'
df = load_xpt(FER)
save_to_postgres(df, "raw_blood_ferritin", engine)
# Out:
# raw_blood_ferritin saved to PostgreSQL

# %%
IRON = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/11.P_FETIB.xpt'
df = load_xpt(IRON)
save_to_postgres(df, "raw_blood_iron_status", engine)
# Out:
# raw_blood_iron_status saved to PostgreSQL

# %%
TFR = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/23.P_TFR.xpt'
df = load_xpt(TFR)
save_to_postgres(df, "raw_blood_transferrin", engine)
# Out:
# raw_blood_transferrin saved to PostgreSQL

# %%
FOL = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/12.P_FOLATE.xpt'
df = load_xpt(FOL)
save_to_postgres(df, "raw_blood_folate", engine)
# Out:
# raw_blood_folate saved to PostgreSQL

# %%
FOL_FORM = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/13.P_FOLFMS.xpt'
df = load_xpt(FOL_FORM)
save_to_postgres(df, "raw_blood_folate_forms", engine)
# Out:
# raw_blood_folate_forms saved to PostgreSQL

# %%
GHB = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/14.P_GHB.xpt'
df = load_xpt(GHB)
save_to_postgres(df, "raw_blood_glycohemoglobin", engine)
# Out:
# raw_blood_glycohemoglobin saved to PostgreSQL

# %%
CRP = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/15.P_HSCRP.xpt'
df = load_xpt(CRP)
save_to_postgres(df, "raw_blood_crp", engine)
# Out:
# raw_blood_crp saved to PostgreSQL

# %%
MERCURY = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/16.P_IHGEM.xpt'
df = load_xpt(MERCURY)
save_to_postgres(df, "raw_blood_mercury", engine)
# Out:
# raw_blood_mercury saved to PostgreSQL

# %%
INS = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/17.P_INS.xpt'
df = load_xpt(INS)
save_to_postgres(df, "raw_blood_insulin", engine)
# Out:
# raw_blood_insulin saved to PostgreSQL

# %%
PBCD = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/18.P_PBCD.xpt'
df = load_xpt(PBCD)
save_to_postgres(df, "raw_blood_pbcd", engine)
# Out:
# raw_blood_pbcd saved to PostgreSQL

# %%
PFAS = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/19.P_PFAS.xpt'
df = load_xpt(PFAS)
save_to_postgres(df, "raw_blood_pfas", engine)
# Out:
# raw_blood_pfas saved to PostgreSQL

# %%
GLU = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/20.P_GLU.xpt'
df = load_xpt(GLU)
save_to_postgres(df, "raw_blood_fasting_glucose", engine)
# Out:
# raw_blood_fasting_glucose saved to PostgreSQL

# %%
SEXH = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/21.P_TST.xpt'
df = load_xpt(SEXH)
save_to_postgres(df, "raw_blood_sex_hormones", engine)
# Out:
# raw_blood_sex_hormones saved to PostgreSQL

# %%
CMP = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/22.P_BIOPRO.xpt'
df = load_xpt(CMP)
save_to_postgres(df, "raw_blood_cmp", engine)
# Out:
# raw_blood_cmp saved to PostgreSQL

# %%
VOCB = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/blood/24.P_VOCWB.xpt'
df = load_xpt(VOCB)
save_to_postgres(df, "raw_blood_voc", engine)
# Out:
# raw_blood_voc saved to PostgreSQL

# %%
pd.set_option('display.max_rows', None)

tables = pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
ORDER BY table_name;
""", engine)

tables
# Out:
#                             table_name
# 0                         adult_cohort
# 1                        anthropometry
# 2              carbohydrate_metabolism
# 3                             cbc_diff
# 4                            clean_bmx
# 5                   clean_demographics
# 6                         demographics
# 7                               df_cra
# 8               diabetes_questionnaire
# 9                      fasting_glucose
# 10                                 hdl
# 11                      hemoglobin_a1c
# 12                     hormone_dataset
# 13                   hormone_dataset_f
# 14                   hormone_dataset_m
# 15                             insulin
# 16                       raw_blood_agp
# 17                       raw_blood_cbc
# 18           raw_blood_chromium_cobalt
# 19                       raw_blood_cmp
# 20                       raw_blood_cmv
# 21                  raw_blood_cotinine
# 22                       raw_blood_crp
# ...

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:rsc@localhost:5432/NHANES_20172020
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/NHANES_20172020'
