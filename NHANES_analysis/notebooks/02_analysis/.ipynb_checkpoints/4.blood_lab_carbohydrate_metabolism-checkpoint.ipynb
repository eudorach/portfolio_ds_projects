# %% [markdown]
# # Association Between Carbohydrate Metabolism Markers and Obesity in Adults without Diabetes: A Cross-Sectional NHANES Analysis
#
# ### Methods
# **Data Source**
#
# This analysis used publicly available data from the National Health and Nutrition Examination Survey (NHANES), a cross-sectional survey designed to assess the health and nutritional status of adults in the United States.
#
# **Study Population**
#
# Participants with complete data on body mass index (BMI), fasting glucose, fasting insulin, hemoglobin A1c (HbA1c), age, sex, and race/ethnicity were included. The final analytic sample consisted of 3,146 individuals.
#
# **Variables**
#
# Outcome variable:
# * Body Mass Index (BMI)
# * Primary predictors:
# * Fasting glucose (mg/dL)
# * Fasting insulin (µU/mL)
# * Hemoglobin A1c (%)
#
# Covariates:
# * Age (years)
# * Sex
# * Race/ethnicity (categorical)
# * Statistical Analysis
#
# All analyses were conducted using ordinary least squares (OLS) linear regression.
#
# The modeling strategy included:
#
# **Univariate regression models**
#
# BMI was regressed separately on:
# * fasting glucose
# * fasting insulin
# * HbA1c
#
# **Multivariable regression models**
#
# BMI was regressed simultaneously on metabolic biomarkers with adjustment for:
# * age
# * sex
# * race/ethnicity
#
# **Correlation analysis**
#
# Pearson correlation coefficients were calculated between BMI and each metabolic biomarker overall and stratified by sex.
#
# Model assumptions were evaluated using residual diagnostics and distributional summaries.
#
# ### Results
# Descriptive Associations (Correlations)
#
# Overall correlations with BMI were:
#
# * Fasting insulin: r = 0.41
# * Fasting glucose: r = 0.23
# * HbA1c: r = 0.21
#
# Sex-stratified correlations:
#
# Fasting insulin
# * Males: r = 0.42
# * Females: r = 0.43
#
# Fasting glucose
# * Males: r = 0.23
# * Females: r = 0.26
#
# HbA1c
# * Males: r = 0.15
# * Females: r = 0.26
#
# **Univariate Regression Models**
#
# All three metabolic markers were significantly associated with BMI in unadjusted models.
#
# * Fasting glucose showed a positive association with BMI (β ≈ 0.18, p < 0.001)
# * Fasting insulin showed the strongest association (β ≈ 0.22, p < 0.001)
# * HbA1c was also positively associated with BMI (β ≈ 4.8, p < 0.001)
#
# Each model showed statistically significant improvement over the null model, with insulin explaining the greatest proportion of variance among single predictors.
#
# **Multivariable Regression Models**
#
# In adjusted models including age, sex, race/ethnicity, and multiple metabolic biomarkers:
#
# * Insulin remained a strong independent predictor of BMI (β ≈ 0.20, p < 0.001)
# * HbA1c remained significant but attenuated when insulin was included (β ≈ 3.3, p < 0.001)
# * Fasting glucose remained significant but weaker in magnitude (β ≈ 0.18, p < 0.001)
#
# Model fit improved with inclusion of multiple biomarkers:
#
# * R² increased from ~0.12 (glucose-only) to ~0.24 (combined model)
# * Covariates
#     * Sex was consistently associated with higher BMI in females compared to males.
#     * Age showed a small inverse association with BMI in fully adjusted models.
#     * Race/ethnicity effects were variable across models, with one subgroup showing consistently lower BMI estimates.
#
# ### Interpretation
#
# This analysis demonstrates a consistent and biologically coherent relationship between markers of glycemic regulation and body mass index in a U.S. adult population.
#
# **Key Findings**
# * Fasting insulin is the strongest and most stable correlate of BMI.
# Across both correlation and regression analyses, insulin showed the largest and most consistent association with BMI, suggesting that insulin resistance physiology is more tightly linked to adiposity than glucose-based markers.
# * Fasting glucose shows a moderate association with BMI.
# While statistically significant, glucose demonstrated weaker associations compared to insulin, consistent with its tighter physiological regulation.
# * HbA1c shows weaker but sex-dependent associations.
# HbA1c was modestly associated with BMI overall, but exhibited a clear sex difference, with stronger correlations in females (r = 0.26) compared to males (r = 0.15). This suggests potential sex-specific differences in long-term glycemic exposure or glycation dynamics relative to adiposity.
# * Multivariable models confirm partial independence of biomarkers.
# Insulin and HbA1c remained significant when included in the same model, indicating that they capture overlapping but distinct aspects of metabolic dysregulation.
#
# ### Biological Interpretation
#
# The pattern of results supports a model in which BMI is more strongly linked to insulin resistance than to glycemic outcomes alone. Fasting insulin likely reflects early compensatory hyperinsulinemia associated with adiposity, whereas fasting glucose and HbA1c reflect downstream glycemic control and longer-term metabolic exposure.
#
# The observed sex differences in HbA1c associations may reflect differences in fat distribution, hormonal influences on glucose metabolism, or differences in red blood cell turnover affecting HbA1c measurement.
#
# ### Limitations
# Cross-sectional design prevents causal inference.
# Residual confounding from diet, physical activity, medication use, and socioeconomic status is likely.
# Biomarkers were analyzed linearly; potential nonlinear relationships were not fully explored.
# Race/ethnicity categories may mask heterogeneity within groups.
#
# ### Conclusion
#
# In a nationally representative sample, fasting insulin demonstrated the strongest association with BMI, supporting its role as a key marker of obesity-related insulin resistance. HbA1c showed moderate associations with notable sex differences, while fasting glucose exhibited weaker associations. Together, these findings suggest that insulin-based measures may be more sensitive indicators of adiposity-related metabolic dysregulation than glucose-based measures alone.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import math
import scipy.stats as stats
from math import erf, sqrt
from math import atanh, sqrt

# %%
from sqlalchemy import create_engine, text

# Create engine and connect
engine = create_engine('postgresql://postgres:rsc@localhost:5432/NHANES_20172020')

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:rsc@localhost:5432/NHANES_20172020
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/NHANES_20172020'

# %%
''' %%sql

CREATE TABLE carbohydrate_metabolism AS

SELECT d.participant_id,
    d.age_year,
    d.gender,
    d.race,
    a.bmi,
    dq.doctor_told_you_have_diabetes,
    f.fasting_glucose_mg_dl,
    i.insulin_μu_ml,
    hgb.glycohemoglobin_percent
FROM demographics d
JOIN anthropometry a 
    ON d.participant_id = a.participant_id
JOIN diabetes_questionnaire dq
    ON d.participant_id = dq.participant_id
JOIN fasting_glucose f
    ON d.participant_id = f.participant_id
JOIN insulin i
    ON d.participant_id = i.participant_id
JOIN hemoglobin_a1c hgb
    ON d.participant_id = hgb.participant_id'''
# Out:
# ' %%sql\n\nCREATE TABLE carbohydrate_metabolism AS\n\nSELECT d.participant_id,\n    d.age_year,\n    d.gender,\n    d.race,\n    a.bmi,\n    dq.doctor_told_you_have_diabetes,\n    f.fasting_glucose_mg_dl,\n    i.insulin_μu_ml,\n    hgb.glycohemoglobin_percent\nFROM demographics d\nJOIN anthropometry a \n    ON d.participant_id = a.participant_id\nJOIN diabetes_questionnaire dq\n    ON d.participant_id = dq.participant_id\nJOIN fasting_glucose f\n    ON d.participant_id = f.participant_id\nJOIN insulin i\n    ON d.participant_id = i.participant_id\nJOIN hemoglobin_a1c hgb\n    ON d.participant_id = hgb.participant_id'

# %%
df = pd.read_sql('SELECT * FROM carbohydrate_metabolism', engine)

# %%
df = df[df['doctor_told_you_have_diabetes'] == 2]
df = df[df['age_year'] >= 18]
df = df[df['glycohemoglobin_percent'] <= 6.4]

# %% [markdown]
# ### Fasting Glucose

# %%
df.describe()
# Out:
#        participant_id     age_year       gender         race          bmi  \
# count     3158.000000  3158.000000  3158.000000  3158.000000  3146.000000
# mean    117155.388854    46.677644     1.525332     3.473084    29.041195
# std       4457.960757    18.072828     0.499437     1.601711     7.311378
# min     109271.000000    18.000000     1.000000     1.000000    15.500000
# 25%     113380.250000    31.000000     1.000000     3.000000    24.100000
# 50%     117224.000000    46.000000     2.000000     3.000000    27.800000
# 75%     120951.750000    61.000000     2.000000     4.000000    32.500000
# max     124822.000000    80.000000     2.000000     7.000000    92.300000
#
#        doctor_told_you_have_diabetes  fasting_glucose_mg_dl  insulin_μu_ml  \
# count                         3158.0            3158.000000    3158.000000
# mean                             2.0             101.674478      12.540994
# std                              0.0              11.662574      13.432665
# ...

# %%
sns.histplot(data=df, x='bmi')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %%
df.isna().sum()
# Out:
# participant_id                    0
# age_year                          0
# gender                            0
# race                              0
# bmi                              12
# doctor_told_you_have_diabetes     0
# fasting_glucose_mg_dl             0
# insulin_μu_ml                     0
# glycohemoglobin_percent           0
# dtype: int64

# %%
df = df.dropna()

# %%
sns.histplot(data=df, x='fasting_glucose_mg_dl')
plt.title('Fasting Glucose Distribution')
plt.xlabel('Fasting Glucose (mg/dL)')
plt.ylabel('Count')
plt.show()

#the histogram looks a little right skewed but it looks fairly normally distributed

# %%
df['fasting_glucose_mg_dl'].median()
# Out:
# 100.0

# %%
df['fasting_glucose_mg_dl'].skew()
# Out:
# 1.4831377508627581

# %%
df['fasting_glucose_mg_dl'].quantile([0.95, 0.99])
# Out:
# 0.95    122.0
# 0.99    136.0
# Name: fasting_glucose_mg_dl, dtype: float64

# %%
sns.regplot(data=df, x='fasting_glucose_mg_dl',y='bmi')
plt.title("Fasting Glucose and BMI")
plt.xlabel('Fasting Glucose (mg/dL)')
plt.ylabel('BMI')
plt.show()

# %%
df[['bmi','fasting_glucose_mg_dl']].corr()
# Out:
#                             bmi  fasting_glucose_mg_dl
# bmi                    1.000000               0.239755
# fasting_glucose_mg_dl  0.239755               1.000000

# %%
stats.pearsonr(df['bmi'],df['fasting_glucose_mg_dl'])
# Out:
# PearsonRResult(statistic=0.23975472869434009, pvalue=2.260777771593015e-42)

# %% [markdown]
# #### Males

# %%
df['gender'].value_counts()
# Out:
# 2.0    1656
# 1.0    1490
# Name: gender, dtype: int64

# %%
df['gender_label'] = df['gender'].map({1:'Male',2:'Female'})

# %%
df.describe(include='all')
# Out:
#         participant_id     age_year       gender         race          bmi  \
# count      3146.000000  3146.000000  3146.000000  3146.000000  3146.000000
# unique             NaN          NaN          NaN          NaN          NaN
# top                NaN          NaN          NaN          NaN          NaN
# freq               NaN          NaN          NaN          NaN          NaN
# mean     117153.090591    46.636046     1.526383     3.469485    29.041195
# std        4458.594228    18.057462     0.499383     1.600037     7.311378
# min      109271.000000    18.000000     1.000000     1.000000    15.500000
# 25%      113380.250000    31.000000     1.000000     3.000000    24.100000
# 50%      117213.000000    46.000000     2.000000     3.000000    27.800000
# 75%      120951.750000    61.000000     2.000000     4.000000    32.500000
# max      124822.000000    80.000000     2.000000     7.000000    92.300000
#
# ...

# %%
df_male = df[df['gender_label']=='Male']
df_female = df[df['gender_label']=='Female']

# %%
df_male.describe(include='all')
# Out:
#         participant_id     age_year  gender         race          bmi  \
# count      1490.000000  1490.000000  1490.0  1490.000000  1490.000000
# unique             NaN          NaN     NaN          NaN          NaN
# top                NaN          NaN     NaN          NaN          NaN
# freq               NaN          NaN     NaN          NaN          NaN
# mean     117195.102685    46.737584     1.0     3.441611    28.313289
# std        4455.243512    18.355427     0.0     1.585152     6.151846
# min      109271.000000    18.000000     1.0     1.000000    15.500000
# 25%      113378.250000    31.000000     1.0     3.000000    24.300000
# 50%      117379.000000    46.000000     1.0     3.000000    27.500000
# 75%      120955.250000    62.000000     1.0     4.000000    31.300000
# max      124822.000000    80.000000     1.0     7.000000    86.200000
#
#         doctor_told_you_have_diabetes  fasting_glucose_mg_dl  insulin_μu_ml  \
# ...

# %%
sns.regplot(data=df_male, x='fasting_glucose_mg_dl', y='bmi')
plt.title('Fasting Glucose vs BMI (Male)')
plt.xlabel('Fasting Glucose (mg/dL)')
plt.ylabel('BMI')
plt.show()

# %%
df_male[['fasting_glucose_mg_dl','bmi']].corr()
# Out:
#                        fasting_glucose_mg_dl       bmi
# fasting_glucose_mg_dl               1.000000  0.235297
# bmi                                 0.235297  1.000000

# %%
df_male['fasting_glucose_mg_dl'].quantile([0.95, 0.99])
# Out:
# 0.95    123.00
# 0.99    136.11
# Name: fasting_glucose_mg_dl, dtype: float64

# %%
stats.pearsonr(df_male['fasting_glucose_mg_dl'], df_male['bmi'])
# Out:
# PearsonRResult(statistic=0.23529692933174756, pvalue=3.43299180437455e-20)

# %% [markdown]
# #### Female

# %%
df_female.describe()
# Out:
#        participant_id     age_year  gender         race          bmi  \
# count     1656.000000  1656.000000  1656.0  1656.000000  1656.000000
# mean    117115.289855    46.544686     2.0     3.494565    29.696135
# std       4462.614383    17.790161     0.0     1.613379     8.162569
# min     109286.000000    18.000000     2.0     1.000000    15.500000
# 25%     113385.500000    32.000000     2.0     3.000000    23.900000
# 50%     117127.000000    46.000000     2.0     3.000000    28.100000
# 75%     120927.750000    60.000000     2.0     4.000000    33.625000
# max     124813.000000    80.000000     2.0     7.000000    92.300000
#
#        doctor_told_you_have_diabetes  fasting_glucose_mg_dl  insulin_μu_ml  \
# count                         1656.0            1656.000000    1656.000000
# mean                             2.0             100.356884      12.457500
# std                              0.0              12.001815      11.964982
# ...

# %%
sns.regplot(data=df_female,x='fasting_glucose_mg_dl',y='bmi')
plt.title('Fasting Glucose vs BMI (Females)')
plt.xlabel('Fasting Glucose (mg/dL)')
plt.ylabel('BMI')
plt.show()

# %%
df_female['fasting_glucose_mg_dl'].quantile([0.95,0.99])
# Out:
# 0.95    120.25
# 0.99    136.00
# Name: fasting_glucose_mg_dl, dtype: float64

# %%
stats.pearsonr(df_female['fasting_glucose_mg_dl'],df_female['bmi'])
# Out:
# PearsonRResult(statistic=0.2675528760576684, pvalue=1.5303614733776655e-28)

# %%
df_female[['fasting_glucose_mg_dl','bmi']].corr()
# Out:
#                        fasting_glucose_mg_dl       bmi
# fasting_glucose_mg_dl               1.000000  0.267553
# bmi                                 0.267553  1.000000

# %% [markdown]
# ### Fasting Insulin
#
# Insulin is a hormone that is secreted for blood sugar regulation. It helps to move the sugar in the bloodstream into cells so that the energy can be utilized.
#
# Obese population generally has insulin resistance due to the high volume of adiposity. When there is insulin resistance, there is a lot of insulin that gets produced. The tissues are not as responsive to the hormone for sugar uptake.
#
# The NHANES dataset collected fasting insulin levels. According to Up to Date, normal serum fasting insulin level is <20 microunits/mL; <138.9 pmol/L (SI).

# %%
sns.histplot(data=df, x='insulin_μu_ml')
plt.title('Fasting Insulin (μu/mL) Distribution')
plt.ylabel('Count')
plt.xlabel('Fasting Insulin (μu/mL)')
plt.show()

# %%
df['insulin_μu_ml'].quantile([.95,.99])
# Out:
# 0.95    30.850
# 0.99    61.784
# Name: insulin_μu_ml, dtype: float64

# %%
sns.regplot(data=df, x='insulin_μu_ml', y='bmi')
plt.title('Fasting Insulin vs BMI')
plt.xlabel('Fasting Insulin (μu/mL)')
plt.ylabel('BMI')
plt.show()

# %%
df[['bmi','insulin_μu_ml']].corr()
# Out:
#                     bmi  insulin_μu_ml
# bmi            1.000000       0.413595
# insulin_μu_ml  0.413595       1.000000

# %%
stats.pearsonr(df['bmi'], df['insulin_μu_ml'])
# Out:
# PearsonRResult(statistic=0.4135949249555145, pvalue=2.841863575991982e-130)

# %% [markdown]
# #### Gender Stratification
#
# **Males**

# %%
sns.regplot(data=df_male, x='insulin_μu_ml', y='bmi')
plt.title('Fasting Insulin vs BMI (Males)')
plt.xlabel('Fasting Insulin (μu/ml)')
plt.ylabel('BMI')
plt.show()

# %%
stats.pearsonr(df_male['insulin_μu_ml'], df_male['bmi'])
# Out:
# PearsonRResult(statistic=0.42656294727198696, pvalue=6.167939371637208e-67)

# %% [markdown]
# **Females**

# %%
df_female.describe()
# Out:
#        participant_id     age_year  gender         race          bmi  \
# count     1656.000000  1656.000000  1656.0  1656.000000  1656.000000
# mean    117115.289855    46.544686     2.0     3.494565    29.696135
# std       4462.614383    17.790161     0.0     1.613379     8.162569
# min     109286.000000    18.000000     2.0     1.000000    15.500000
# 25%     113385.500000    32.000000     2.0     3.000000    23.900000
# 50%     117127.000000    46.000000     2.0     3.000000    28.100000
# 75%     120927.750000    60.000000     2.0     4.000000    33.625000
# max     124813.000000    80.000000     2.0     7.000000    92.300000
#
#        doctor_told_you_have_diabetes  fasting_glucose_mg_dl  insulin_μu_ml  \
# count                         1656.0            1656.000000    1656.000000
# mean                             2.0             100.356884      12.457500
# std                              0.0              12.001815      11.964982
# ...

# %%
sns.regplot(data=df_female, x='insulin_μu_ml',y='bmi')
plt.title('Fasting Insulin vs BMI (Females)')
plt.xlabel('Fasting Insulin (μu/ml)')
plt.ylabel('BMI')
plt.show()

# %%
stats.pearsonr(df_female['insulin_μu_ml'], df_female['bmi'])
# Out:
# PearsonRResult(statistic=0.4317278356724777, pvalue=3.7238825977052034e-76)

# %% [markdown]
# ### Hemoglobin A1c
#
# Hemoglobin A1c (HgbA1c) is a way to diagnose diabetes, as it measures the average blood glucose saturation level in the past 3 months from the day of the blood draw. The ranges for the A1c is as follows:
#
# * under 5.7% = normal
# * 5.7-6.4% = prediabetes
# * above 6.5% = diabetes

# %%
sns.histplot(data=df, x='glycohemoglobin_percent')
plt.title('Hemoglobin A1c Distribution')
plt.xlabel('HgbA1c (%)')
plt.ylabel('Count')
plt.show()

# %%
sns.regplot(data=df, x='glycohemoglobin_percent',y='bmi')
plt.title('Hemoglobin A1c vs BMI')
plt.xlabel('Hemoglobin A1c (%)')
plt.ylabel('BMI')
plt.show()

# %%
df[['bmi','glycohemoglobin_percent']].corr()
# Out:
#                               bmi  glycohemoglobin_percent
# bmi                      1.000000                 0.212499
# glycohemoglobin_percent  0.212499                 1.000000

# %%
stats.pearsonr(df['bmi'],df['glycohemoglobin_percent'])
# Out:
# PearsonRResult(statistic=0.21249873744408268, pvalue=1.891955225622899e-33)

# %% [markdown]
# #### Gender Stratification
#
# **Male**

# %%
sns.regplot(data=df_male,x='glycohemoglobin_percent',y='bmi')
plt.title('Hemoglobin A1c vs BMI (Males)')
plt.xlabel('Hemoglobin A1c (%)')
plt.ylabel('BMI')
plt.show()

# %%
stats.pearsonr(df_male['glycohemoglobin_percent'], df_male['bmi'])
# Out:
# PearsonRResult(statistic=0.15779328489257247, pvalue=9.114341402626671e-10)

# %% [markdown]
# **Females**

# %%
sns.regplot(data=df_female, x='glycohemoglobin_percent',y='bmi')
plt.title('Hemoglobin A1c vs BMI (Females)')
plt.xlabel('Hemoglobin A1c (%)')
plt.ylabel('BMI')
plt.show()

# %%
stats.pearsonr(df_female['glycohemoglobin_percent'], df_female['bmi'])
# Out:
# PearsonRResult(statistic=0.26070709998066866, pvalue=3.90972394014303e-27)

# %% [markdown]
# ### Multivariable Regression

# %%
df[['bmi','insulin_μu_ml','glycohemoglobin_percent','fasting_glucose_mg_dl', 'gender', 'race']].corr()
# Out:
#                               bmi  insulin_μu_ml  glycohemoglobin_percent  \
# bmi                      1.000000       0.413595                 0.212499
# insulin_μu_ml            0.413595       1.000000                 0.158575
# glycohemoglobin_percent  0.212499       0.158575                 1.000000
# fasting_glucose_mg_dl    0.239755       0.368741                 0.398186
# gender                   0.094451      -0.007329                -0.015055
# race                    -0.096368      -0.055814                 0.039284
#
#                          fasting_glucose_mg_dl    gender      race
# bmi                                   0.239755  0.094451 -0.096368
# insulin_μu_ml                         0.368741 -0.007329 -0.055814
# glycohemoglobin_percent               0.398186 -0.015055  0.039284
# fasting_glucose_mg_dl                 1.000000 -0.118234 -0.061980
# gender                               -0.118234  1.000000  0.016527
# ...

# %% [markdown]
# #### Fasting Glucose Model

# %%
import statsmodels.formula.api as smf

# %%
model_glucose = smf.ols(
    "bmi ~ fasting_glucose_mg_dl + age_year + C(gender) + C(race)",
    data=df
).fit()

print(model_glucose.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    bmi   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     55.84
# Date:                Wed, 20 May 2026   Prob (F-statistic):           2.57e-85
# Time:                        16:42:03   Log-Likelihood:                -10513.
# No. Observations:                3146   AIC:                         2.104e+04
# Df Residuals:                    3137   BIC:                         2.110e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                11.8035      1.163     10.151      0.000       9.524      14.083
# ...

# %% [markdown]
# #### Fasting Insulin

# %%
model_insulin = smf.ols(
    "bmi ~ insulin_μu_ml + age_year + C(gender) + C(race)",
    data=df
).fit()

print(model_insulin.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    bmi   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     107.3
# Date:                Wed, 20 May 2026   Prob (F-statistic):          1.16e-158
# Time:                        16:42:04   Log-Likelihood:                -10342.
# No. Observations:                3146   AIC:                         2.070e+04
# Df Residuals:                    3137   BIC:                         2.076e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           25.4779      0.460     55.435      0.000      24.577      26.379
# ...

# %% [markdown]
# #### Hemoglobin A1c

# %%
model_hba1c = smf.ols(
    "bmi ~ glycohemoglobin_percent + age_year + C(gender) + C(race)",
    data=df
).fit()

print(model_hba1c.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    bmi   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     44.87
# Date:                Wed, 20 May 2026   Prob (F-statistic):           1.14e-68
# Time:                        16:42:04   Log-Likelihood:                -10552.
# No. Observations:                3146   AIC:                         2.112e+04
# Df Residuals:                    3137   BIC:                         2.118e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.6481      1.888      2.462      0.014       0.946       8.350
# ...

# %% [markdown]
# #### Combined Multivariable Model with Hemoglobin A1c and Fasting Insulin vs BMI

# %%
model_combined = smf.ols(
    "bmi ~ insulin_μu_ml + glycohemoglobin_percent + age_year + C(gender) + C(race)",
    data=df
).fit()

print(model_combined.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    bmi   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     108.8
# Date:                Wed, 20 May 2026   Prob (F-statistic):          6.75e-178
# Time:                        16:42:04   Log-Likelihood:                -10295.
# No. Observations:                3146   AIC:                         2.061e+04
# Df Residuals:                    3136   BIC:                         2.067e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   8.9640      1.750      5.123      0.000       5.533      12.395
# ...

# %% [markdown]
# #### Logistic Regression

# %%
df['obese'] = (df['bmi'] >= 30).astype(int)

# %%
df.head()
# Out:
#    participant_id  age_year  gender  race   bmi  \
# 1        109271.0      49.0     1.0   3.0  29.7
# 4        109282.0      76.0     1.0   3.0  26.6
# 5        109286.0      33.0     2.0   6.0  28.9
# 8        109297.0      30.0     2.0   6.0  23.2
# 9        109300.0      54.0     2.0   6.0  29.6
#
#    doctor_told_you_have_diabetes  fasting_glucose_mg_dl  insulin_μu_ml  \
# 1                            2.0                  103.0          16.96
# 4                            2.0                   95.0           7.49
# 5                            2.0                   92.0          16.46
# 8                            2.0                   92.0           7.61
# 9                            2.0                  103.0          11.47
#
#    glycohemoglobin_percent gender_label  gender_binary  obese
# 1                      5.6         Male              0      0
# 4                      5.5         Male              0      0
# ...

# %%
X = df[['insulin_μu_ml','glycohemoglobin_percent', 'gender_binary']]
y = df['obese']

X = sm.add_constant(X)

model = sm.Logit(y,X).fit()

print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.538140
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:                  obese   No. Observations:                 3146
# Model:                          Logit   Df Residuals:                     3142
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 20 May 2026   Pseudo R-squ.:                  0.1825
# Time:                        16:42:05   Log-Likelihood:                -1693.0
# converged:                       True   LL-Null:                       -2070.9
# Covariance Type:            nonrobust   LLR p-value:                1.611e-163
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
np.exp(model.params)
# Out:
# const                      0.004777
# insulin_μu_ml              1.137158
# glycohemoglobin_percent    1.731046
# gender_binary              1.590266
# dtype: float64
