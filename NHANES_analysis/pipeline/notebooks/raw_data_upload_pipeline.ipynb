# %%
import pandas as pd
import numpy as np
import pyreadstat
from sqlalchemy import create_engine
import sys
sys.path.append("..")
from nhanes_utils import (
    save_to_postgres,
    load_xpt,
    validate
)
sys.path.append("..")
from raw_table_loading import ingest_folder

# -------------------------------
# CONFIG
# -------------------------------

DB_URI = 'postgresql://postgres:rsc@localhost:5432/nhanes'
engine = create_engine(DB_URI)

# %%
import os

os.getcwd()
# Out:
# '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/pipeline/notebooks'

# %%
TABLE_NAME_MAP = {
    "P_SSAGP":   "raw_blood_agp",
    "P_CBC":     "raw_blood_cbc",
    "P_CRCO":    "raw_blood_chromium_cobalt",
    "P_BIOPRO":  "raw_blood_cmp",
    "P_CMV":     "raw_blood_cmv",
    "P_COT":     "raw_blood_cotinine",
    "P_HSCRP":   "raw_blood_crp",
    "P_ETHOX":   "raw_blood_ethylene_oxide",
    "P_GLU":     "raw_blood_fasting_glucose",
    "P_FERTIN":  "raw_blood_ferritin",
    "P_FOLATE":  "raw_blood_folate",
    "P_FOLFMS":  "raw_blood_folate_forms",
    "P_GHB":     "raw_blood_glycohemoglobin",
    "P_HDL":     "raw_blood_hdl",
    "P_INS":     "raw_blood_insulin",
    "P_FETIB":   "raw_blood_iron_status",
    "P_IHGEM":   "raw_blood_mercury",
    "P_PBCD":    "raw_blood_pbcd",
    "P_PFAS":    "raw_blood_pfas",
    "P_TST":     "raw_blood_sex_hormones",
    "P_TCHOL":   "raw_blood_total_cholesterol",
    "P_TFR":     "raw_blood_transferrin",
    "P_TRIGLY":  "raw_blood_triglyceride",
    "P_VOCWB":   "raw_blood_voc",
    "P_UCM":     "raw_urine_chromium",
    "P_FR":      "raw_urine_flame_retardants",
    "P_SSFR":    "raw_urine_flame_retardants_surplus",
    "P_UAS":     "raw_urine_speciated_arsenic",
    "P_UTAS":    "raw_urine_total_arsenic",
    "P_ALB_CR":  "raw_urine_albcr",
    "P_OPD":     "raw_urine_insecticide",
    "P_UIO":     "raw_urine_iodine",
    "P_UHG":     "raw_urine_mercury",
    "P_UM":      "raw_urine_metals",
    "P_UNI":     "raw_urine_nickel",
    "P_PERNT":   "raw_urine_perc_nit_thio",
    "P_UCPREG":  "raw_urine_pregnancy",
    "P_UVOC":    "raw_urine_voc",
    "P_UVOC2":   "raw_urine_voc_2",
    "P_BMX": "raw_bmx",
    "BPOscillometric_P_BPXO.xpt": "raw_blood_pressure",
    "P_DEMO": "raw_demographics"
}

# %%
path = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw'

ingest_folder(path, engine, TABLE_NAME_MAP)
# Out:
# raw_blood_crp saved to PostgreSQL
# Loaded P_HSCRP.xpt -> raw_blood_crp
# raw_blood_folate_forms saved to PostgreSQL
# Loaded P_FOLFMS.xpt -> raw_blood_folate_forms
# raw_p_hepe saved to PostgreSQL
# Loaded P_HEPE.xpt -> raw_p_hepe
# raw_urine_metals saved to PostgreSQL
# Loaded P_UM.xpt -> raw_urine_metals
# raw_blood_triglyceride saved to PostgreSQL
# Loaded P_TRIGLY.xpt -> raw_blood_triglyceride
# raw_p_hepa saved to PostgreSQL
# Loaded P_HEPA.xpt -> raw_p_hepa
# raw_urine_insecticide saved to PostgreSQL
# Loaded P_OPD.xpt -> raw_urine_insecticide
# raw_p_hepc saved to PostgreSQL
# Loaded P_HEPC.xpt -> raw_p_hepc
# raw_bposcillometric_p_bpxo saved to PostgreSQL
# Loaded BPOscillometric_P_BPXO.xpt -> raw_bposcillometric_p_bpxo
# raw_blood_pbcd saved to PostgreSQL
# Loaded P_PBCD.xpt -> raw_blood_pbcd
# raw_p_hepbd saved to PostgreSQL
# Loaded P_HEPBD.xpt -> raw_p_hepbd
# raw_demographics saved to PostgreSQL
# Loaded P_DEMO.xpt -> raw_demographics
# raw_urine_voc saved to PostgreSQL
# Loaded P_UVOC.xpt -> raw_urine_voc
# raw_urine_mercury saved to PostgreSQL
# Loaded P_UHG.xpt -> raw_urine_mercury
# raw_p_hepb_s saved to PostgreSQL
# Loaded P_HEPB_S.xpt -> raw_p_hepb_s
# raw_blood_cmv saved to PostgreSQL
# Loaded P_CMV.xpt -> raw_blood_cmv
# raw_blood_folate saved to PostgreSQL
# Loaded P_FOLATE.xpt -> raw_blood_folate
# raw_blood_fasting_glucose saved to PostgreSQL
# Loaded P_GLU.xpt -> raw_blood_fasting_glucose
# raw_blood_insulin saved to PostgreSQL
# Loaded P_INS.xpt -> raw_blood_insulin
# raw_blood_voc saved to PostgreSQL
# Loaded P_VOCWB.xpt -> raw_blood_voc
# raw_blood_agp saved to PostgreSQL
# Loaded P_SSAGP.xpt -> raw_blood_agp
# raw_p_paq saved to PostgreSQL
# Loaded P_PAQ.xpt -> raw_p_paq
# raw_blood_cbc saved to PostgreSQL
# Loaded P_CBC.xpt -> raw_blood_cbc
# raw_blood_hdl saved to PostgreSQL
# Loaded P_HDL.xpt -> raw_blood_hdl
# raw_blood_total_cholesterol saved to PostgreSQL
# Loaded P_TCHOL.xpt -> raw_blood_total_cholesterol
# raw_blood_chromium_cobalt saved to PostgreSQL
# Loaded P_CRCO.xpt -> raw_blood_chromium_cobalt
# raw_urine_total_arsenic saved to PostgreSQL
# Loaded P_UTAS.xpt -> raw_urine_total_arsenic
# raw_blood_iron_status saved to PostgreSQL
# Loaded P_FETIB.xpt -> raw_blood_iron_status
# raw_urine_voc_2 saved to PostgreSQL
# Loaded P_UVOC2.xpt -> raw_urine_voc_2
# raw_blood_cotinine saved to PostgreSQL
# Loaded P_COT.xpt -> raw_blood_cotinine
# raw_urine_flame_retardants saved to PostgreSQL
# Loaded P_FR.xpt -> raw_urine_flame_retardants
# raw_urine_perc_nit_thio saved to PostgreSQL
# Loaded P_PERNT.xpt -> raw_urine_perc_nit_thio
# raw_urine_iodine saved to PostgreSQL
# Loaded P_UIO.xpt -> raw_urine_iodine
# raw_blood_mercury saved to PostgreSQL
# Loaded P_IHGEM.xpt -> raw_blood_mercury
# raw_blood_ferritin saved to PostgreSQL
# Loaded P_FERTIN.xpt -> raw_blood_ferritin
# raw_blood_pfas saved to PostgreSQL
# Loaded P_PFAS.xpt -> raw_blood_pfas
# raw_bmx saved to PostgreSQL
# Loaded P_BMX.xpt -> raw_bmx
# raw_blood_ethylene_oxide saved to PostgreSQL
# Loaded P_ETHOX.xpt -> raw_blood_ethylene_oxide
# raw_urine_albcr saved to PostgreSQL
# Loaded P_ALB_CR.xpt -> raw_urine_albcr
# raw_blood_transferrin saved to PostgreSQL
# Loaded P_TFR.xpt -> raw_blood_transferrin
# raw_blood_cmp saved to PostgreSQL
# Loaded P_BIOPRO.xpt -> raw_blood_cmp
# raw_urine_pregnancy saved to PostgreSQL
# Loaded P_UCPREG.xpt -> raw_urine_pregnancy
# raw_urine_flame_retardants_surplus saved to PostgreSQL
# Loaded P_SSFR.xpt -> raw_urine_flame_retardants_surplus
# raw_urine_chromium saved to PostgreSQL
# Loaded P_UCM.xpt -> raw_urine_chromium
# raw_blood_glycohemoglobin saved to PostgreSQL
# Loaded P_GHB.xpt -> raw_blood_glycohemoglobin
# raw_urine_speciated_arsenic saved to PostgreSQL
# Loaded P_UAS.xpt -> raw_urine_speciated_arsenic
# raw_blood_sex_hormones saved to PostgreSQL
# Loaded P_TST.xpt -> raw_blood_sex_hormones
# raw_urine_nickel saved to PostgreSQL
# Loaded P_UNI.xpt -> raw_urine_nickel

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:rsc@localhost:5432/nhanes
# Out:
# Connecting and switching to connection 'postgresql://postgres:***@localhost:5432/nhanes'

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM raw_demographics;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/nhanes'
# 1 rows affected.
# +-------+
# | count |
# +-------+
# | 15560 |
# +-------+

# %%
pd.set_option('display.max_rows', None)

tables = pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
ORDER BY table_name;
""", engine)

tables
# Out:
#                             table_name
# 0                   biomarker_registry
# 1                        raw_blood_agp
# 2                        raw_blood_cbc
# 3            raw_blood_chromium_cobalt
# 4                        raw_blood_cmp
# 5                        raw_blood_cmv
# 6                   raw_blood_cotinine
# 7                        raw_blood_crp
# 8             raw_blood_ethylene_oxide
# 9            raw_blood_fasting_glucose
# 10                  raw_blood_ferritin
# 11                    raw_blood_folate
# 12              raw_blood_folate_forms
# 13           raw_blood_glycohemoglobin
# 14                       raw_blood_hdl
# 15                   raw_blood_insulin
# 16               raw_blood_iron_status
# 17                   raw_blood_mercury
# 18                      raw_blood_pbcd
# 19                      raw_blood_pfas
# 20              raw_blood_sex_hormones
# 21         raw_blood_total_cholesterol
# 22               raw_blood_transferrin
# 23              raw_blood_triglyceride
# 24                       raw_blood_voc
# 25                             raw_bmx
# 26          raw_bposcillometric_p_bpxo
# 27                    raw_demographics
# 28                          raw_p_hepa
# 29                        raw_p_hepb_s
# 30                         raw_p_hepbd
# 31                          raw_p_hepc
# 32                          raw_p_hepe
# 33                           raw_p_paq
# 34               raw_speciated_arsenic
# 35                   raw_total_arsenic
# 36                     raw_urine_albcr
# 37                  raw_urine_chromium
# 38          raw_urine_flame_retardants
# 39  raw_urine_flame_retardants_surplus
# 40               raw_urine_insecticide
# 41                    raw_urine_iodine
# 42                   raw_urine_mercury
# 43                    raw_urine_metals
# 44                    raw_urine_nickel
# 45             raw_urine_perc_nit_thio
# 46                 raw_urine_pregnancy
# 47         raw_urine_speciated_arsenic
# 48             raw_urine_total_arsenic
# 49                       raw_urine_voc
# 50                     raw_urine_voc_2

# %%
#Medical History tables

med_hx = {
    "P_DBQ" : "raw_diet_nutrition",
    "P_IMQ" : "raw_immunization_hx",
    "P_MCQ" : "raw_medical_history",
    "P_PAQ" : "raw_physical_activity",
    "P_RXQ_RX" : "raw_prescription_meds",
    "P_RHQ" : "raw_reproductive_health",
    "P_SMQ" : "raw_smoking_history",
    "P_SMQFAM" : "raw_household_smoker",
    "P_SMQRTU" : "raw_recent_tobacco_use",
    "P_SMQSHS" : "raw_secondhand_smoke",
    "P_WHQ" : "raw_weight_history",
    "RXQ_DRUG" : "drug_information"
}

# %%
path = '/Users/Rachel/Documents/GitHub/portfolio_ds_projects/NHANES_analysis/data/raw/medical_history'

ingest_folder(path, engine, med_hx)
# Out:
# raw_prescription_meds saved to PostgreSQL
# Loaded P_RXQ_RX.xpt -> raw_prescription_meds
# raw_recent_tobacco_use saved to PostgreSQL
# Loaded P_SMQRTU.xpt -> raw_recent_tobacco_use
# raw_reproductive_health saved to PostgreSQL
# Loaded P_RHQ.xpt -> raw_reproductive_health
# raw_weight_history saved to PostgreSQL
# Loaded P_WHQ.xpt -> raw_weight_history
# raw_household_smoker saved to PostgreSQL
# Loaded P_SMQFAM.xpt -> raw_household_smoker
# raw_medical_history saved to PostgreSQL
# Loaded P_MCQ.xpt -> raw_medical_history
# drug_information saved to PostgreSQL
# Loaded RXQ_DRUG.xpt -> drug_information
# raw_immunization_hx saved to PostgreSQL
# Loaded P_IMQ.xpt -> raw_immunization_hx
# raw_physical_activity saved to PostgreSQL
# Loaded P_PAQ.xpt -> raw_physical_activity
# raw_smoking_history saved to PostgreSQL
# Loaded P_SMQ.xpt -> raw_smoking_history
# raw_diet_nutrition saved to PostgreSQL
# Loaded P_DBQ.xpt -> raw_diet_nutrition
# raw_p_bpxo saved to PostgreSQL
# Loaded P_BPXO.xpt -> raw_p_bpxo
# raw_secondhand_smoke saved to PostgreSQL
# Loaded P_SMQSHS.xpt -> raw_secondhand_smoke
